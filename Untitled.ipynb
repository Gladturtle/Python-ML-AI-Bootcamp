# %%
import numpy as np
import pandas as pd 
from plotly import __version__
from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode
import cufflinks as cf

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(data = np.random.randn(100,4),columns = 'A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0  -0.182182 -0.883280  0.517902  0.146257
# 1  -2.419945  0.702087 -0.167915  0.099640
# 2  -1.017670 -0.199785  0.417906  0.907386
# 3   1.062040 -0.531223 -2.350784 -1.859448
# 4  -0.399957  1.169591  1.102708 -0.856327
# ..       ...       ...       ...       ...
# 95  1.063500 -0.500278  0.081983 -0.356598
# 96 -0.790794 -0.176259 -0.442932  0.480137
# 97 -0.172962 -0.391206 -1.804964  0.281886
# 98 -1.188210 -0.209914 -0.197226 -0.323023
# 99 -1.137901 -0.991260  0.997224  1.360817
#
# [100 rows x 4 columns]

# %%
dict = {'Catagories':['A','B','C'],'Values':[32,43,50]}
df2 = pd.DataFrame(dict)

# %%
df2
# Out:
#   Catagories  Values
# 0          A      32
# 1          B      43
# 2          C      50

# %%
df.iplot()

# %%
df.iplot(kind = 'scatter',x = 'A',y = 'B',mode = 'markers')

# %%
df[['A','D']].iplot(kind = 'box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface')

# %%
df.iplot(kind = 'area',bins=20)
